# %% [markdown]
# # Entregável 1 - visão computacional

# %%
# %matplotlib inline
import cv2
from matplotlib import pyplot as plt
import numpy as np
import time as t
print "OpenCV Version : %s " % cv2.__version__
# Out:
# OpenCV Version : 2.4.8

# %% [markdown]
# # Equalização de histograma

# %%
rintin = cv2.imread("RinTinTin.jpg")

# %%
rintin.shape
# Out:
# (240, 320, 3)

# %%
rintin_gray = cv2.cvtColor(rintin, cv2.COLOR_RGB2GRAY)

# %%
rintin_gray.shape
# Out:
# (240, 320)

# %%
plt.imshow(rintin_gray, cmap="Greys_r")

# %%
hist,bins = np.histogram(rintin_gray.flatten(),256,[0,256])

cdf = hist.cumsum()
cdf_normalized = cdf * hist.max()/ cdf.max()

plt.plot(cdf_normalized, color = 'b')
plt.hist(rintin_gray.flatten(),256,[0,256], color = 'r')
plt.xlim([0,256])
plt.legend(('cdf','histogram'), loc = 'upper left')
plt.show()

# %% [markdown]
# ## Atividade 1
#
# Realize as seguintes atividades:
#
# 1. O histograma fornecido aproveita bem as faixas de cores?
# 2. Equalize o histograma de maneira que a cumulativa seja uma função linear na diagonal do gráfico
# 3. Plote a imagem desenhada

# %% [markdown]
# 1- Não aproveita, pois seus valores estão somente de 0 até 50 e não de 0 até 255.

# %%
valor_mult = max(bins)/max(rintin_gray.flatten())
rintin_gray_correct = [m*valor_mult for m in rintin_gray.flatten()]
valor_mult
# Out:
# 4.4137931034482758

# %%
hist,bins = np.histogram(rintin_gray_correct,256,[0,256])

cdf = hist.cumsum()
cdf_normalized = cdf * hist.max()/ cdf.max()

plt.plot(cdf_normalized, color = 'b')
plt.hist(rintin_gray_correct,256,[0,256], color = 'r')
plt.xlim([0,256])
plt.legend(('cdf','histogram'), loc = 'upper left')
plt.show()

# %%
rintin_equalized = cv2.equalizeHist(rintin_gray)

# %%
hist,bins = np.histogram(rintin_equalized.flatten(),256,[0,256])

cdf = hist.cumsum()
cdf_normalized = cdf * hist.max()/ cdf.max()

plt.plot(cdf_normalized, color = 'b')
plt.hist(rintin_equalized.flatten(),256,[0,256], color = 'r')
plt.xlim([0,256])
plt.legend(('cdf','histogram'), loc = 'upper left')
plt.show()

# %%
plt.imshow(rintin_equalized, cmap="Greys_r")

# %% [markdown]
# 2.

# %% [markdown]
# ## Atividade 2

# %% [markdown]
# Leia com a OpenCV a figura abaixo:
#
# ![](hall_box_battery1.jpg)
#
# Separe os canais  R e B das imagens e analise seus histogramas.
#
# 1. A partir dos canais R e B e da análise do histograma é possível identificar a caixa vermelha e a bateria azul?
#
# 1. Crie uma imagem numpy em que somente os pixels da caixa vermelha estão brancos e faça seu plot aqui

# %%
imagem_hall = cv2.imread("hall_box_battery1.jpg")
img_hsv=cv2.cvtColor(imagem_hall, cv2.COLOR_BGR2HSV)

# %%
img_hsv.shape
# Out:
# (3006, 5344, 3)

# %%
plt.imshow(img_hsv)

# %%
lower_red = np.array([0,50,50])
upper_red = np.array([10,255,255])
mask0 = cv2.inRange(img_hsv, lower_red, upper_red)

lower_red = np.array([170,50,50])
upper_red = np.array([180,255,255])
mask1 = cv2.inRange(img_hsv, lower_red, upper_red)

mask = mask0+mask1

output_img = imagem_hall.copy()
output_img[np.where(mask==0)] = 0

output_hsv = img_hsv.copy()
output_hsv[np.where(mask==0)] = 0

output=cv2.cvtColor(output_hsv, cv2.COLOR_HSV2RGB)

# %%
plt.imshow(output, cmap = "Greys_r")

# %%
lower_blue = np.array([90,30,30])
upper_blue = np.array([130,255,255])
mask2 = cv2.inRange(img_hsv, lower_blue, upper_blue)

output_img = imagem_hall.copy()
output_img[np.where(mask2==0)] = 0

output_hsv = img_hsv.copy()
output_hsv[np.where(mask2==0)] = 0

output=cv2.cvtColor(output_hsv, cv2.COLOR_HSV2RGB)

# %%
plt.imshow(output, cmap = "Greys_r")

# %%
output_final = imagem_hall.copy()
output_final[np.where(mask != 0)] = 255

# %%
plt.imshow(output_final)
